# %% [markdown]
# # Capstone
#
# Filtering data for only patents in US and combining 2009-2019, 2020 was separate. At the time 2021 and beyond not yet availible.

# %%
import pandas as pd
import numpy as np

# %%
two19 = pd.read_csv('2019.csv')

# %%
two19.columns
# Out:
# Index(['patent_number', 'assignee', 'grant_year', 'application_year',
#        'application_number', 'country', 'city', 'state', 'county',
#        'ipc_section', 'team_size', 'inventors', 'men_inventors',
#        'women_inventors', 'inventor_name1', 'male_flag1', 'inventor_id1',
#        'inventor_name2', 'male_flag2', 'inventor_id2', 'inventor_name3',
#        'male_flag3', 'inventor_id3', 'inventor_name4', 'male_flag4',
#        'inventor_id4', 'inventor_name5', 'male_flag5', 'inventor_id5',
#        'inventor_name6', 'male_flag6', 'inventor_id6', 'inventor_name7',
#        'male_flag7', 'inventor_id7', 'inventor_name8', 'male_flag8',
#        'inventor_id8', 'inventor_name9', 'male_flag9', 'inventor_id9'],
#       dtype='object')

# %%
two19.tail()
# Out:
#        patent_number                                         assignee  \
# 382559       RE47664                                       APPLE INC.
# 382560       RE47689                          F. HOFFMANN-LA ROCHE AG
# 382561       RE47746                                      RUSOH, INC.
# 382562       RE47782  TAIWAN SEMICONDUCTOR MANUFACTURING COMPANY LTD.
# 382563       RE47788                         KABUSHIKI KAISHA TOSHIBA
#
#         grant_year  application_year  application_number country        city  \
# 382559        2019              2017            29622909      US   Cupertino
# 382560        2019              2017            15695299      CH       Basel
# 382561        2019              2018            29651249      US  Eau Claire
# 382562        2019              2016            15392532      TW     Hsinchu
# 382563        2019              2018            16025680      JP       Tokyo
#
#        state       county ipc_section  ...    inventor_id6  \
# ...

# %%
two19['country'].unique()
# Out:
# array(['IT', 'US', 'CN', 'JP', 'CA', 'DE', 'NL', 'GB', 'DK', 'FR', 'CH',
#        'HK', 'KR', 'LU', 'TW', 'AU', 'VG', 'SG', 'IL', 'SE', 'IE', 'BE',
#        'BB', 'ES', 'AT', 'BM', 'MY', 'FI', 'IN', 'NO', 'LT', 'TR', 'MT',
#        'LI', nan, 'SA', 'BR', 'NZ', 'ZA', 'MX', 'IR', 'MO', 'TH', 'PL',
#        'CZ', 'HU', 'KY', 'UA', 'RU', 'CY', 'ID', 'DO', 'BS', 'GR', 'CO',
#        'QA', 'CL', 'LV', 'VN', 'EG', 'AE', 'SC', 'CR', 'PT', 'EE', 'IS',
#        'GI', 'WS', 'IM', 'KW', 'SK', 'MC', 'JE', 'AN', 'RS', 'SI', 'LK',
#        'un', 'PE', 'AR', 'AD', 'PH', 'JO', 'CU', 'CK', 'UY', 'AI', 'MU',
#        'BG', 'BZ', 'KZ', 'TT', 'LB', 'BN', 'HR', 'CW', 'VE', 'BY', 'PK',
#        'BD', 'PA', 'RO', 'UK', 'GG', 'ML', 'TN', 'MH', 'OM', 'DM', 'DD',
#        'EC', 'NI', 'JM', 'SM', 'KP', 'KN', 'JA', 'DL', 'CS', 'MR', 'FO',
#        'TK', 'BO', 'KH', 'MD'], dtype=object)

# %%
two19[two19['country'].isna()]
# Out:
#        patent_number                            assignee  grant_year  \
# 598         10166417          SCOTT HEALTH & SAFETY LTD.        2019
# 923         10166785                   CHARTA GROUP, INC        2019
# 2042        10167993     OCEANEERING INTERNATIONAL, INC.        2019
# 3813        10169832        INSTANT ACCESS NETWORKS, LLC        2019
# 4306        10170350                  NAURA AKRION, INC.        2019
# ...              ...                                 ...         ...
# 377167       D865147  KINGKAR ECO-TECHNOLOGIES CO., LTD.        2019
# 377943       D866092   SHANGHAI QINXU INDUSTRY CO., LTD.        2019
# 379227       D867688                   DELCA CORPORATION        2019
# 380557       D869329                           GARANT GP        2019
# 382007       D871093             MUTSUMI GIKEN CO., LTD.        2019
#
#         application_year  application_number country  \
# 598                 2015            14797933     NaN
# ...

# %%
two19[two19['country'] == 'US']
# Out:
#        patent_number                                  assignee  grant_year  \
# 1           10165722                           DEERE & COMPANY        2019
# 2           10165723                      BAYER CROPSCIENCE LP        2019
# 3           10165724                    CRARY INDUSTRIES, INC.        2019
# 4           10165725                           DEERE & COMPANY        2019
# 5           10165726                CNH INDUSTRIAL AMERICA LLC        2019
# ...              ...                                       ...         ...
# 382550       RE47549                           S.R. SMITH, LLC        2019
# 382554       RE47572           THE CHARLES MACHINE WORKS, INC.        2019
# 382558       RE47657  TOSHIBA AMERICA BUSINESS SOLUTIONS, INC.        2019
# 382559       RE47664                                APPLE INC.        2019
# 382561       RE47746                               RUSOH, INC.        2019
#
# ...

# %%
two18 = pd.read_csv('2018.csv')
sum(two18['country'].isna())
# Out:
# 469

# %%
df = pd.DataFrame()

#works on one but not many ? 
def read_filter(file_name):
    new = pd.read_csv(str(file_name)+'.csv')
    new = new[new['country'] == 'US']
    #df2 = df.append(new)
    return new

# %%
read_filter(2019)
# Out:
# /var/folders/8w/lcbkp3d94ms0tyj03qhvhby40000gn/T/ipykernel_69669/3902920134.py:1: DtypeWarning: Columns (0,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   read_filter(2019)
#        patent_number                                  assignee  grant_year  \
# 1           10165722                           DEERE & COMPANY        2019
# 2           10165723                      BAYER CROPSCIENCE LP        2019
# 3           10165724                    CRARY INDUSTRIES, INC.        2019
# 4           10165725                           DEERE & COMPANY        2019
# 5           10165726                CNH INDUSTRIAL AMERICA LLC        2019
# ...              ...                                       ...         ...
# 382550       RE47549                           S.R. SMITH, LLC        2019
# 382554       RE47572           THE CHARLES MACHINE WORKS, INC.        2019
# 382558       RE47657  TOSHIBA AMERICA BUSINESS SOLUTIONS, INC.        2019
# ...

# %%
for i in range(2009, 2020, 1):
    print(i)
# Out:
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019

# %%
for i in range(2009, 2019, 1):
    read_filter(i)
# Out:
# /var/folders/8w/lcbkp3d94ms0tyj03qhvhby40000gn/T/ipykernel_67676/1301831092.py:2: DtypeWarning: Columns (0,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   read_filter(i)
# /var/folders/8w/lcbkp3d94ms0tyj03qhvhby40000gn/T/ipykernel_67676/1301831092.py:2: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   read_filter(i)

# %%
#killed the kernal
df = pd.DataFrame()
for i in range(2009, 2020):
    dfi = read_filter(i)
    df = df.append(dfi)
# Out:
# /var/folders/8w/lcbkp3d94ms0tyj03qhvhby40000gn/T/ipykernel_69669/1911723640.py:3: DtypeWarning: Columns (0,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   dfi = read_filter(i)
# /var/folders/8w/lcbkp3d94ms0tyj03qhvhby40000gn/T/ipykernel_69669/1911723640.py:3: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   dfi = read_filter(i)

# %%
#df.sort_values('grant_year', ascending = False )
# Out:
#        patent_number                                assignee  grant_year  \
# 1           10165722                         DEERE & COMPANY        2019
# 124998      10299047  MEYER SOUND LABORATORIES, INCORPORATED        2019
# 124992      10299040                               DTS, INC.        2019
# 124991      10299039                              APPLE INC.        2019
# 124990      10299038                        BOSE CORPORATION        2019
# ...              ...                                     ...         ...
# 248345      10430240              PALANTIR TECHNOLOGIES INC.        2019
# 248344      10430239                              CLARI INC.        2019
# 248343      10430238               CAPITAL ONE SERVICES, LLC        2019
# 248339      10430234                           RED HAT, INC.        2019
# 382561       RE47746                             RUSOH, INC.        2019
#
#         application_year  application_number country        city state  \
# ...

# %%
df2009 = read_filter(2009)
df2010 = read_filter(2010)
df2011 = read_filter(2011)
df2012 = read_filter(2012)
df2013 = read_filter(2013)
df2014 = read_filter(2014)
df2015 = read_filter(2015)
df2016 = read_filter(2016)
df2017 = read_filter(2017)
df2018 = read_filter(2018)
df2019 = read_filter(2019)
# Out:
# /var/folders/8w/lcbkp3d94ms0tyj03qhvhby40000gn/T/ipykernel_69774/1727663658.py:1: DtypeWarning: Columns (0,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   df2009 = read_filter(2009)
# /var/folders/8w/lcbkp3d94ms0tyj03qhvhby40000gn/T/ipykernel_69774/1727663658.py:2: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   df2010 = read_filter(2010)
# /var/folders/8w/lcbkp3d94ms0tyj03qhvhby40000gn/T/ipykernel_69774/1727663658.py:3: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   df2011 = read_filter(2011)
# /var/folders/8w/lcbkp3d94ms0tyj03qhvhby40000gn/T/ipykernel_69774/1727663658.py:4: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   df2012 = read_filter(2012)
# ...

# %%
#default behavior limits the number of rows/columns you can see
#turn that off

pd.set_option('display.max_columns', None)

# %%
dfall = pd.concat([df2009, df2010, df2011, df2012, df2013, 
                   df2014, df2015, df2016, df2017, df2018, df2019])
# Out:
#        patent_number                             assignee  grant_year  \
# 382561       RE47746                          RUSOH, INC.        2019
# 124951      10298995                  DISH NETWORK L.L.C.        2019
# 124984      10299032                           APPLE INC.        2019
# 124983      10299031                     BOSE CORPORATION        2019
# 124981      10299029                           APPLE INC.        2019
# ...              ...                                  ...         ...
# 118767       7600532               INGERSOLL-RAND COMPANY        2009
# 118768       7600533   CALIFORNIA INSTITUTE OF TECHNOLOGY        2009
# 118769       7600534  SCHLUMBERGER TECHNOLOGY CORPORATION        2009
# 118771       7600537         HONEYWELL INTERNATIONAL INC.        2009
# 0            7472428                           NIKE, INC.        2009
#
#         application_year  application_number country        city state  \
# ...

# %%
dfall.sort_values('grant_year', ascending = False )
# Out:
#        patent_number                             assignee  grant_year  \
# 382561       RE47746                          RUSOH, INC.        2019
# 124951      10298995                  DISH NETWORK L.L.C.        2019
# 124984      10299032                           APPLE INC.        2019
# 124983      10299031                     BOSE CORPORATION        2019
# 124981      10299029                           APPLE INC.        2019
# ...              ...                                  ...         ...
# 118767       7600532               INGERSOLL-RAND COMPANY        2009
# 118768       7600533   CALIFORNIA INSTITUTE OF TECHNOLOGY        2009
# 118769       7600534  SCHLUMBERGER TECHNOLOGY CORPORATION        2009
# 118771       7600537         HONEYWELL INTERNATIONAL INC.        2009
# 0            7472428                           NIKE, INC.        2009
#
#         application_year  application_number country        city state  \
# ...

# %%
dfall.to_csv("2009_2019.csv")

# %%
df2020 = read_filter(2020)
# Out:
# /var/folders/8w/lcbkp3d94ms0tyj03qhvhby40000gn/T/ipykernel_69774/4130591173.py:1: DtypeWarning: Columns (0,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   df2020 = read_filter(2020)

# %%
df2020.to_csv("2020.csv")
